# %% [markdown]
# # Training the model

# %%
# importing necessary libraries
import os
from ultralytics import YOLO
import torch
from IPython.display import Image, display

# %%
# verify CUDA availability (GPU)
print(f"CUDA available: {torch.cuda.is_available()}") # gpu nh h :(
# Out:
# CUDA available: False

# %%
# initialize YOLO model
model = YOLO('yolo11n.pt')

# %%
# train the model
results = model.train(
    data='dataset/yolo/data.yaml',
    epochs=50,
    imgsz=640,
    batch=8,
    device='cuda' if torch.cuda.is_available() else 'cpu',
    name='parking_cars_yolo',
    optimizer='auto',
    lr0=0.01,
    cos_lr=True,
    augment=True,
    patience=30,
    seed=42
)
# Out:
# Ultralytics 8.3.85  Python-3.12.4 torch-2.6.0+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# ...

# %%
# evaluate on test set
metrics = model.val(split='test')
# Out:
# Ultralytics 8.3.85  Python-3.12.4 torch-2.6.0+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning E:\ParkingSpaceDetection\dataset\yolo\test\labels... 20 images, 5 backgrounds, 0 corrupt: 100%|██████████
# val: New cache created: E:\ParkingSpaceDetection\dataset\yolo\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:03<0
#                    all         20         15      0.997          1      0.995      0.922
# Speed: 6.0ms preprocess, 155.3ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs\detect\parking_cars_yolo2

# %%
# run inference
results = model.predict(
    source='dataset/yolo/test/images',
    conf=0.5,
    save=True,
    show_labels=True,
    show_conf=True
)
# Out:
# image 1/20 E:\ParkingSpaceDetection\dataset\yolo\test\images\image-160-_jpg.rf.65c03bcf651fcbf132e93614937e2678.jpg: 640x640 1 cars-sUYr, 271.0ms
# image 2/20 E:\ParkingSpaceDetection\dataset\yolo\test\images\image-175-_jpg.rf.530b5472e58a6d4afdbf032e13791c5d.jpg: 640x640 1 cars-sUYr, 156.0ms
# image 3/20 E:\ParkingSpaceDetection\dataset\yolo\test\images\image-189-_jpg.rf.63ffcc3b1d0ff074b787962807091839.jpg: 640x640 1 cars-sUYr, 156.7ms
# image 4/20 E:\ParkingSpaceDetection\dataset\yolo\test\images\image-203-_jpg.rf.26d944f9b017088e1aec02d2818f11a9.jpg: 640x640 1 cars-sUYr, 154.2ms
# image 5/20 E:\ParkingSpaceDetection\dataset\yolo\test\images\image-214-_jpg.rf.4b833b18a7e3d88cbf2142f43230e103.jpg: 640x640 1 cars-sUYr, 165.1ms
# image 6/20 E:\ParkingSpaceDetection\dataset\yolo\test\images\image-229-_jpg.rf.1efc273754c76a56c4352ca9df4fac44.jpg: 640x640 1 cars-sUYr, 172.7ms
# ...

# %% [markdown]
# # Testing the model

# %%
model = YOLO("runs/detect/parking_cars_yolo/weights/best.pt")
model.export(format='onnx')
# Out:
# Ultralytics 8.3.85  Python-3.12.4 torch-2.6.0+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'runs\detect\parking_cars_yolo\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.48...
# ONNX: export success  1.8s, saved as 'runs\detect\parking_cars_yolo\weights\best.onnx' (10.1 MB)
#
# Export complete (2.0s)
# Results saved to E:\ParkingSpaceDetection\runs\detect\parking_cars_yolo\weights
# Predict:         yolo predict task=detect model=runs\detect\parking_cars_yolo\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs\detect\parking_cars_yolo\weights\best.onnx imgsz=640 data=dataset/yolo/data.yaml
# Visualize:       https://netron.app
# 'runs\\detect\\parking_cars_yolo\\weights\\best.onnx'

# %%
model.save('models/best_model.pt')

# %%
test_images_dir = "dataset/yolo/test/images"

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def test_and_visualize(model, test_dir, num_samples=3):
    test_images = [os.path.join(test_dir, f) for f in os.listdir(test_dir)]
    
    results = model.predict(
        source=test_images,
        conf=0.5,
        save=True,
        save_txt=True,
        save_conf=True,
        exist_ok=True
    )
    
    plt.figure(figsize=(15, 10))
    for i, (img_path, result) in enumerate(zip(test_images[:num_samples], results[:num_samples])):
        plt.subplot(num_samples, 2, 2*i+1)
        plt.imshow(plt.imread(img_path))
        plt.title('Original Image')
        plt.axis('off')
        
        plt.subplot(num_samples, 2, 2*i+2)
        plotted = result.plot()  # Returns RGB numpy array
        plt.imshow(plotted)
        plt.title('Prediction')
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
test_and_visualize(model, test_images_dir, num_samples=8)
# Out:
# 0: 640x640 1 cars-sUYr, 58.8ms
# 1: 640x640 1 cars-sUYr, 58.8ms
# 2: 640x640 1 cars-sUYr, 58.8ms
# 3: 640x640 1 cars-sUYr, 58.8ms
# 4: 640x640 1 cars-sUYr, 58.8ms
# 5: 640x640 1 cars-sUYr, 58.8ms
# 6: 640x640 1 cars-sUYr, 58.8ms
# 7: 640x640 1 cars-sUYr, 58.8ms
# 8: 640x640 1 cars-sUYr, 58.8ms
# 9: 640x640 1 cars-sUYr, 58.8ms
# 10: 640x640 1 cars-sUYr, 58.8ms
# 11: 640x640 1 cars-sUYr, 58.8ms
# 12: 640x640 (no detections), 58.8ms
# 13: 640x640 1 cars-sUYr, 58.8ms
# 14: 640x640 1 cars-sUYr, 58.8ms
# 15: 640x640 1 cars-sUYr, 58.8ms
# 16: 640x640 (no detections), 58.8ms
# 17: 640x640 (no detections), 58.8ms
# 18: 640x640 (no detections), 58.8ms
# 19: 640x640 (no detections), 58.8ms
# Speed: 2.9ms preprocess, 58.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict
# 15 labels saved to runs\detect\predict\labels
