# %% [markdown]
# # Training the model

# %%
# importing necessary libraries
import os
from ultralytics import YOLO
import torch
from IPython.display import Image, display

# %%
# verify CUDA availability (GPU)
print(f"CUDA available: {torch.cuda.is_available()}") # gpu nh h :(
# Out:
# CUDA available: False

# %%
# initialize YOLO model
model = YOLO('yolo11n.pt')

# %%
# train the model
results = model.train(
    data='data/yolo12/data.yaml',
    epochs=10,
    imgsz=640,
    batch=8,
    device='cuda' if torch.cuda.is_available() else 'cpu',
    name='parking_cars_yolo12',
    optimizer='auto',
    lr0=0.01,
    cos_lr=True,
    augment=True,
    patience=30,
    seed=42
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.78 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.76  Python-3.11.8 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# engine\trainer: task=detect, mode=train, model=yolo11n.pt, data=data/yolo12/data.yaml, epochs=10, time=None, patience=30, batch=8, imgsz=640, save=True, save_period=-1, cache=False, device=cpu, workers=8, project=None, name=parking_cars_yolo12, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=42, deterministic=True, single_cls=False, rect=False, cos_lr=True, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=True, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\parking_cars_yolo12
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs\detect\parking_cars_yolo12', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# train: Scanning E:\ParkingSpaceDetection\data\yolo12\train\labels... 140 images, 35 backgrounds, 0 corrupt: 100%|██████
# train: New cache created: E:\ParkingSpaceDetection\data\yolo12\train\labels.cache
# val: Scanning E:\ParkingSpaceDetection\data\yolo12\valid\labels... 40 images, 10 backgrounds, 0 corrupt: 100%|█████████
# val: New cache created: E:\ParkingSpaceDetection\data\yolo12\valid\labels.cache
# Plotting labels to runs\detect\parking_cars_yolo12\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\parking_cars_yolo12
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:08<0
#                    all         40         30     0.0025          1      0.879      0.582
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:07<0
#                    all         40         30      0.822      0.926      0.927      0.622
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:07<0
#                    all         40         30      0.593        0.9      0.684       0.48
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:07<0
#                    all         40         30      0.745        0.8      0.768      0.521
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:07<0
#                    all         40         30       0.94        0.9      0.972      0.797
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:07<0
#                    all         40         30       0.95        0.8      0.916      0.758
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:07<0
#                    all         40         30      0.966          1      0.994       0.81
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:06<0
#                    all         40         30      0.967      0.991      0.993      0.845
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:07<0
#                    all         40         30      0.998          1      0.995      0.873
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:07<0
#                    all         40         30          1      0.997      0.995      0.885
# 10 epochs completed in 0.208 hours.
# Optimizer stripped from runs\detect\parking_cars_yolo12\weights\last.pt, 5.5MB
# Optimizer stripped from runs\detect\parking_cars_yolo12\weights\best.pt, 5.5MB
#
# Validating runs\detect\parking_cars_yolo12\weights\best.pt...
# Ultralytics 8.3.76  Python-3.11.8 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:16<0
#                    all         40         30      0.998      0.967      0.994      0.879
# Speed: 2.3ms preprocess, 288.7ms inference, 0.0ms loss, 97.3ms postprocess per image
# Results saved to runs\detect\parking_cars_yolo12

# %%
# evaluate on test set
metrics = model.val(split='test')
# Out:
# Ultralytics 8.3.76  Python-3.11.8 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning E:\ParkingSpaceDetection\data\yolo12\test\labels... 20 images, 5 backgrounds, 0 corrupt: 100%|██████████|
# val: New cache created: E:\ParkingSpaceDetection\data\yolo12\test\labels.cache
#                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:08<0
#                    all         20         15      0.996          1      0.995      0.907
# Speed: 14.7ms preprocess, 292.0ms inference, 0.0ms loss, 93.6ms postprocess per image
# Results saved to runs\detect\parking_cars_yolo122

# %%
# run inference
results = model.predict(
    source='data/yolo/test/images',
    conf=0.5,
    save=True,
    show_labels=True,
    show_conf=True
)
# Out:
# image 1/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-160-_jpg.rf.65c03bcf651fcbf132e93614937e2678.jpg: 640x640 1 cars-sUYr, 708.6ms
# image 2/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-175-_jpg.rf.530b5472e58a6d4afdbf032e13791c5d.jpg: 640x640 1 cars-sUYr, 451.7ms
# image 3/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-189-_jpg.rf.63ffcc3b1d0ff074b787962807091839.jpg: 640x640 1 cars-sUYr, 449.2ms
# image 4/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-203-_jpg.rf.26d944f9b017088e1aec02d2818f11a9.jpg: 640x640 1 cars-sUYr, 448.1ms
# image 5/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-214-_jpg.rf.4b833b18a7e3d88cbf2142f43230e103.jpg: 640x640 1 cars-sUYr, 431.7ms
# image 6/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-229-_jpg.rf.1efc273754c76a56c4352ca9df4fac44.jpg: 640x640 1 cars-sUYr, 445.8ms
# image 7/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-233-_jpg.rf.7e37ca2c8c57607df433a3b485480fd6.jpg: 640x640 1 cars-sUYr, 425.1ms
# image 8/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-235-_jpg.rf.5ca99d4075dab402f3e2658f63728e9b.jpg: 640x640 1 cars-sUYr, 435.1ms
# image 9/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-246-_jpg.rf.8c2ef2f852266191dee88fc76162b5e6.jpg: 640x640 1 cars-sUYr, 422.0ms
# image 10/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-257-_jpg.rf.8fd20794ff825677a34db4351061f7eb.jpg: 640x640 1 cars-sUYr, 427.3ms
# image 11/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-259-_jpg.rf.a9f88ae4b56166ad1a6c9c638d03124d.jpg: 640x640 1 cars-sUYr, 433.5ms
# image 12/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-270-_jpg.rf.69ad6b83e7353e363b6506465f34fca1.jpg: 640x640 1 cars-sUYr, 429.4ms
# image 13/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-284-_jpg.rf.ca84f4c4390a72de765e075bb062618f.jpg: 640x640 1 cars-sUYr, 431.7ms
# image 14/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-291-_jpg.rf.cb24ee66e5713c1f00e2d9b072b44682.jpg: 640x640 1 cars-sUYr, 430.7ms
# image 15/15 E:\ParkingSpaceDetection\data\yolo\test\images\image-296-_jpg.rf.3ad3dab2df0532e356b440d0e4a33e19.jpg: 640x640 1 cars-sUYr, 426.5ms
# Speed: 5.6ms preprocess, 453.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\parking_cars_yolo123

# %% [markdown]
# # Testing the model

# %%
model = YOLO("runs/detect/parking_cars_yolo12/weights/best.pt")
model.export(format='onnx')
# Out:
# Ultralytics 8.3.76  Python-3.11.8 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'runs\detect\parking_cars_yolo12\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.48...
# ONNX: export success  3.8s, saved as 'runs\detect\parking_cars_yolo12\weights\best.onnx' (10.1 MB)
#
# Export complete (4.7s)
# Results saved to E:\ParkingSpaceDetection\runs\detect\parking_cars_yolo12\weights
# Predict:         yolo predict task=detect model=runs\detect\parking_cars_yolo12\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs\detect\parking_cars_yolo12\weights\best.onnx imgsz=640 data=data/yolo12/data.yaml
# Visualize:       https://netron.app
# 'runs\\detect\\parking_cars_yolo12\\weights\\best.onnx'

# %%
model.save('best_model.pt')

# %%
test_images_dir = "data/test"

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def test_and_visualize(model, test_dir, num_samples=3):
    # Get list of test images
    test_images = [os.path.join(test_dir, f) for f in os.listdir(test_dir)]
    
    # Run prediction
    results = model.predict(
        source=test_images,
        conf=0.5,
        save=True,
        save_txt=True,
        save_conf=True,
        exist_ok=True
    )
    
    # Visualize results
    plt.figure(figsize=(15, 10))
    for i, (img_path, result) in enumerate(zip(test_images[:num_samples], results[:num_samples])):
        # Plot original image
        plt.subplot(num_samples, 2, 2*i+1)
        plt.imshow(plt.imread(img_path))
        plt.title('Original Image')
        plt.axis('off')
        
        # Plot predicted image
        plt.subplot(num_samples, 2, 2*i+2)
        plotted = result.plot()  # Returns RGB numpy array
        plt.imshow(plotted)
        plt.title('Prediction')
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
test_and_visualize(model, test_images_dir, num_samples=8)
# Out:
# 0: 640x640 (no detections), 119.9ms
# 1: 640x640 (no detections), 119.9ms
# 2: 640x640 (no detections), 119.9ms
# 3: 640x640 1 cars-sUYr, 119.9ms
# 4: 640x640 1 cars-sUYr, 119.9ms
# 5: 640x640 1 cars-sUYr, 119.9ms
# 6: 640x640 1 cars-sUYr, 119.9ms
# 7: 640x640 1 cars-sUYr, 119.9ms
# Speed: 7.5ms preprocess, 119.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict
# 8 labels saved to runs\detect\predict\labels
